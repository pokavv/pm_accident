# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.rcParams['font.family'] = 'NanumGothic'

df = pd.read_excel('data/PM_accident.xlsx', index_col=0)
df
# Out:
#                Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# NaN  *개인형이동수단(PM) 교통사고 현황         NaN         NaN        NaN        NaN
# NaN                   NaN         NaN         NaN        NaN        NaN
# NaN               - 사고유형별         NaN         NaN        NaN        NaN
# NaN                  발생년도         NaN         NaN       2017        NaN
# NaN              사고유형_대분류    사고유형_중분류        사고유형       사고건수       사망자수
# NaN                  차대사람         횡단중         횡단중          6          0
# NaN                  차대사람       차도통행중       차도통행중          3          0
# NaN                  차대사람  길가장자리구역통행중  길가장자리구역통행중          1          0
# NaN                  차대사람       보도통행중       보도통행중          7          0
# NaN                  차대사람          기타          기타         16          0
# NaN                   차대차        정면충돌        정면충돌          6          0
# NaN                   차대차        측면충돌        측면충돌         28          1
# ...
