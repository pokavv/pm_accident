# %%
from matplotlib import font_manager, rc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

font_name = font_manager.FontProperties(fname='c:/windows/fonts/malgun.ttf').get_name()
rc('font', family=font_name)

# %%
violation = pd.read_csv('violation.csv')
violation
# Out:
#    기준년도  안전운전의무불이행
# 0  2017         87
# 1  2018        143
# 2  2019        265
# 3  2020        529
# 4  2021       1013

# %%
violation.plot(kind='bar', x='기준년도')
# Out:
# <AxesSubplot:xlabel='기준년도'>

# %%
violation2 = pd.read_csv('violation2.csv')
violation2
# Out:
#    기준년도  중앙선침범  신호위반  안전거리미확보  일시정지위반  부당한회전  교차로운행방법위반  보행자보호의무위반  우선권양보불이행  \
# 0  2017      8     4        3       1      1          6          3         0
# 1  2018     15    28        4       0     60          3          2         0
# 2  2019     28    42        9       1     14         24          6         0
# 3  2020     50    75       16       3     23         30         21         0
# 4  2021    107   145       31       5     46         31         40         1
#
#    직진우회전진행방해  차로위반(진로변경)  앞지르기금지위반  과속
# 0          1           0         0   0
# 1          5           2         1   0
# 2         10           1         1   0
# 3         20           1         0   1
# 4         48           4         1   0

# %%
violation2.corr()
# Out:
#                 기준년도     중앙선침범      신호위반   안전거리미확보    일시정지위반     부당한회전  \
# 기준년도        1.000000  0.923238  0.952651  0.934758  0.869626  0.349867
# 중앙선침범       0.923238  1.000000  0.993903  0.997977  0.955427  0.361383
# 신호위반        0.952651  0.993903  1.000000  0.992158  0.933981  0.420483
# 안전거리미확보     0.934758  0.997977  0.992158  1.000000  0.967208  0.316333
# 일시정지위반      0.869626  0.955427  0.933981  0.967208  1.000000  0.135688
# 부당한회전       0.349867  0.361383  0.420483  0.316333  0.135688  1.000000
# 교차로운행방법위반   0.910748  0.783425  0.799299  0.817185  0.813518 -0.054031
# 보행자보호의무위반   0.906207  0.987186  0.976640  0.990944  0.986040  0.293574
# 우선권양보불이행    0.707107  0.916200  0.882471  0.894258  0.838525  0.401431
# 직진우회전진행방해   0.915094  0.999502  0.992998  0.995495  0.949108  0.382288
# 차로위반(진로변경)  0.729800  0.839436  0.853132  0.805439  0.659380  0.761182
# 앞지르기금지위반    0.288675  0.288249  0.322652  0.246032  0.000000  0.640289
# 과속          0.353553  0.117677  0.165847  0.165243  0.279508 -0.135366
#
#             교차로운행방법위반  보행자보호의무위반  우선권양보불이행  직진우회전진행방해  차로위반(진로변경)  앞지르기금지위반  \
# 기준년도         0.910748   0.906207  0.707107   0.915094    0.729800  0.288675
# 중앙선침범        0.783425   0.987186  0.916200   0.999502    0.839436  0.288249
# 신호위반         0.799299   0.976640  0.882471   0.992998    0.853132  0.322652
# 안전거리미확보      0.817185   0.990944  0.894258   0.995495    0.805439  0.246032
# 일시정지위반       0.813518   0.986040  0.838525   0.949108    0.659380  0.000000
# 부당한회전       -0.054031   0.293574  0.401431   0.382288    0.761182  0.640289
# 교차로운행방법위반    1.000000   0.788792  0.510179   0.764408    0.414336  0.054631
# 보행자보호의무위반    0.788792   1.000000  0.881941   0.984451    0.770052  0.135019
# 우선권양보불이행     0.510179   0.881941  1.000000   0.926081    0.884652  0.408248
# 직진우회전진행방해    0.764408   0.984451  0.926081   1.000000    0.854270  0.305365
# 차로위반(진로변경)   0.414336   0.770052  0.884652   0.854270    1.000000  0.662122
# 앞지르기금지위반     0.054631   0.135019  0.408248   0.305365    0.662122  1.000000
# 과속           0.468361   0.227375 -0.250000   0.094983   -0.221163 -0.612372
#
#                   과속
# 기준년도        0.353553
# 중앙선침범       0.117677
# 신호위반        0.165847
# 안전거리미확보     0.165243
# 일시정지위반      0.279508
# 부당한회전      -0.135366
# 교차로운행방법위반   0.468361
# 보행자보호의무위반   0.227375
# 우선권양보불이행   -0.250000
# 직진우회전진행방해   0.094983
# 차로위반(진로변경) -0.221163
# 앞지르기금지위반   -0.612372
# 과속          1.000000

# %%
violation2.plot(kind='bar', x='기준년도', figsize=(9,8))
# Out:
# <AxesSubplot:xlabel='기준년도'>
