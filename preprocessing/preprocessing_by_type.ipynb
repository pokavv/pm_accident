# %%
from matplotlib import font_manager, rc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

font_name = font_manager.FontProperties(fname='c:/windows/fonts/malgun.ttf').get_name()
rc('font', family=font_name)

# %%
df = pd.read_excel('data/accident_사고유형별.xls')
df
# Out:
#                                                  기준년도    합계 합계.1   합계.2  \
# 0                                                기준년도    합계   합계     합계
# 1                                                기준년도    합계   합계     합계
# 2                                                기준년도    합계  횡단중  후진중충돌
# 3                                                사고건수  3421  198      2
# 4                                                사망자수    45    1      0
# 5                                                부상자수  3721  212      2
# 6                                                 NaN   NaN  NaN    NaN
# 7                                                 NaN   NaN  NaN    NaN
# 8                                                 NaN   NaN  NaN    NaN
# 9                                                 NaN   NaN  NaN    NaN
# 10                                                NaN   NaN  NaN    NaN
# 11                                                NaN   NaN  NaN    NaN
# ...

# %%
df = df.drop(df.index[6:21])
df
# Out:
#    기준년도    합계 합계.1   합계.2   합계.3       합계.4     합계.5     합계.6 합계.7 합계.8  ...  \
# 0  기준년도    합계   합계     합계     합계         합계       합계       합계   합계   합계  ...
# 1  기준년도    합계   합계     합계     합계         합계       합계       합계   합계   합계  ...
# 2  기준년도    합계  횡단중  후진중충돌  공작물충돌  주/정차차량 충돌  도로이탈 추락  도로이탈 기타   기타   전도  ...
# 3  사고건수  3421  198      2     36          1        9        4  210  104  ...
# 4  사망자수    45    1      0      2          0        0        0   13    8  ...
# 5  부상자수  3721  212      2     34          1        9        4  200   97  ...
#
#   2018.52 2018.53 2018.54 2018.55 2018.56 2018.57 2018.58 2018.59 2018.60  \
# 0    차대사람     차대차     차대차     차대차     차대차     차대차     차대차     차대차     차대차
# 1      기타      합계      합계      합계      합계      합계    정면충돌    정면충돌    측면충돌
# 2      기타      합계    정면충돌    측면충돌      추돌      기타      합계    정면충돌      합계
# 3      28     141       8      66       8      59       8       8      66
# ...

# %%
df = df.rename(columns=df.iloc[0])
df
# Out:
#    기준년도    합계   합계     합계     합계         합계       합계       합계   합계   합계  ...  \
# 0  기준년도    합계   합계     합계     합계         합계       합계       합계   합계   합계  ...
# 1  기준년도    합계   합계     합계     합계         합계       합계       합계   합계   합계  ...
# 2  기준년도    합계  횡단중  후진중충돌  공작물충돌  주/정차차량 충돌  도로이탈 추락  도로이탈 기타   기타   전도  ...
# 3  사고건수  3421  198      2     36          1        9        4  210  104  ...
# 4  사망자수    45    1      0      2          0        0        0   13    8  ...
# 5  부상자수  3721  212      2     34          1        9        4  200   97  ...
#
#    차대사람  차대차   차대차   차대차  차대차  차대차   차대차   차대차   차대차   차대차
# 0  차대사람  차대차   차대차   차대차  차대차  차대차   차대차   차대차   차대차   차대차
# 1    기타   합계    합계    합계   합계   합계  정면충돌  정면충돌  측면충돌  측면충돌
# 2    기타   합계  정면충돌  측면충돌   추돌   기타    합계  정면충돌    합계  측면충돌
# 3    28  141     8    66    8   59     8     8    66    66
# 4     0    1     0     1    0    0     0     0     1     1
# 5    29  153     9    70   10   64     9     9    70    70
#
# ...

# %%
df = df.drop(df.index[0:2])
df
# Out:
#    기준년도    합계   합계     합계     합계         합계       합계       합계   합계   합계  ...  \
# 2  기준년도    합계  횡단중  후진중충돌  공작물충돌  주/정차차량 충돌  도로이탈 추락  도로이탈 기타   기타   전도  ...
# 3  사고건수  3421  198      2     36          1        9        4  210  104  ...
# 4  사망자수    45    1      0      2          0        0        0   13    8  ...
# 5  부상자수  3721  212      2     34          1        9        4  200   97  ...
#
#   차대사람  차대차   차대차   차대차 차대차 차대차 차대차   차대차 차대차   차대차
# 2   기타   합계  정면충돌  측면충돌  추돌  기타  합계  정면충돌  합계  측면충돌
# 3   28  141     8    66   8  59   8     8  66    66
# 4    0    1     0     1   0   0   0     0   1     1
# 5   29  153     9    70  10  64   9     9  70    70
#
# [4 rows x 255 columns]

# %%
df = df.set_index(['기준년도'])
df
# Out:
#         합계   합계     합계     합계         합계       합계       합계   합계   합계  합계  ...  \
# 기준년도                                                                      ...
# 기준년도    합계  횡단중  후진중충돌  공작물충돌  주/정차차량 충돌  도로이탈 추락  도로이탈 기타   기타   전도  전복  ...
# 사고건수  3421  198      2     36          1        9        4  210  104   2  ...
# 사망자수    45    1      0      2          0        0        0   13    8   0  ...
# 부상자수  3721  212      2     34          1        9        4  200   97   2  ...
#
#      차대사람  차대차   차대차   차대차 차대차 차대차 차대차   차대차 차대차   차대차
# 기준년도
# 기준년도   기타   합계  정면충돌  측면충돌  추돌  기타  합계  정면충돌  합계  측면충돌
# 사고건수   28  141     8    66   8  59   8     8  66    66
# 사망자수    0    1     0     1   0   0   0     0   1     1
# 부상자수   29  153     9    70  10  64   9     9  70    70
#
# [4 rows x 254 columns]

# %%
dft = df.transpose()
pd.set_option('display.max_rows', None)
dft
# Out:
# 기준년도        기준년도  사고건수 사망자수  부상자수
# 합계            합계  3421   45  3721
# 합계           횡단중   198    1   212
# 합계         후진중충돌     2    0     2
# 합계         공작물충돌    36    2    34
# 합계     주/정차차량 충돌     1    0     1
# 합계       도로이탈 추락     9    0     9
# 합계       도로이탈 기타     4    0     4
# 합계            기타   210   13   200
# 합계            전도   104    8    97
# 합계            전복     2    0     2
# 합계         차도통행중    64    0    70
# 합계          전도전복    12    2    10
# 합계    길가장자리구역통행중    34    0    35
# 합계         보도통행중   364    0   375
# 합계            기타   531    0   561
# 합계          정면충돌   156    2   193
# 합계          측면충돌   879   12   996
# 합계            추돌   102    0   126
# 합계            기타   713    5   794
# 합계            합계   198    1   212
# 합계           횡단중   198    1   212
# 합계            합계     2    0     2
# 합계         후진중충돌     2    0     2
# 합계            합계    36    2    34
# 합계         공작물충돌    36    2    34
# 합계            합계     1    0     1
# ...

# %%
df_type = dft.loc[dft.기준년도 != '합계']
df_type = df_type.loc[df_type.기준년도 != '기타']
df_type
# Out:
# 기준년도        기준년도 사고건수 사망자수 부상자수
# 합계           횡단중  198    1  212
# 합계         후진중충돌    2    0    2
# 합계         공작물충돌   36    2   34
# 합계     주/정차차량 충돌    1    0    1
# 합계       도로이탈 추락    9    0    9
# 합계       도로이탈 기타    4    0    4
# 합계            전도  104    8   97
# 합계            전복    2    0    2
# 합계         차도통행중   64    0   70
# 합계          전도전복   12    2   10
# 합계    길가장자리구역통행중   34    0   35
# 합계         보도통행중  364    0  375
# 합계          정면충돌  156    2  193
# 합계          측면충돌  879   12  996
# 합계            추돌  102    0  126
# 합계           횡단중  198    1  212
# 합계         후진중충돌    2    0    2
# 합계         공작물충돌   36    2   34
# 합계     주/정차차량 충돌    1    0    1
# 합계       도로이탈 추락    9    0    9
# 합계       도로이탈 기타    4    0    4
# 합계            전도  104    8   97
# 합계            전복    2    0    2
# 합계          전도전복   12    2   10
# 합계         차도통행중   64    0   70
# 합계    길가장자리구역통행중   34    0   35
# 합계         보도통행중  364    0  375
# 합계          정면충돌  156    2  193
# ...

# %%
df_type.columns = ['사고유형', '사고건수', '사망자수', '부상자수']
df_type
# Out:
#             사고유형 사고건수 사망자수 부상자수
# 합계           횡단중  198    1  212
# 합계         후진중충돌    2    0    2
# 합계         공작물충돌   36    2   34
# 합계     주/정차차량 충돌    1    0    1
# 합계       도로이탈 추락    9    0    9
# 합계       도로이탈 기타    4    0    4
# 합계            전도  104    8   97
# 합계            전복    2    0    2
# 합계         차도통행중   64    0   70
# 합계          전도전복   12    2   10
# 합계    길가장자리구역통행중   34    0   35
# 합계         보도통행중  364    0  375
# 합계          정면충돌  156    2  193
# 합계          측면충돌  879   12  996
# 합계            추돌  102    0  126
# 합계           횡단중  198    1  212
# 합계         후진중충돌    2    0    2
# 합계         공작물충돌   36    2   34
# 합계     주/정차차량 충돌    1    0    1
# 합계       도로이탈 추락    9    0    9
# 합계       도로이탈 기타    4    0    4
# 합계            전도  104    8   97
# 합계            전복    2    0    2
# 합계          전도전복   12    2   10
# 합계         차도통행중   64    0   70
# 합계    길가장자리구역통행중   34    0   35
# 합계         보도통행중  364    0  375
# 합계          정면충돌  156    2  193
# ...

# %%
df_type = df_type.reset_index()
df_type
# Out:
#     index        사고유형 사고건수 사망자수 부상자수
# 0      합계         횡단중  198    1  212
# 1      합계       후진중충돌    2    0    2
# 2      합계       공작물충돌   36    2   34
# 3      합계   주/정차차량 충돌    1    0    1
# 4      합계     도로이탈 추락    9    0    9
# 5      합계     도로이탈 기타    4    0    4
# 6      합계          전도  104    8   97
# 7      합계          전복    2    0    2
# 8      합계       차도통행중   64    0   70
# 9      합계        전도전복   12    2   10
# 10     합계  길가장자리구역통행중   34    0   35
# 11     합계       보도통행중  364    0  375
# 12     합계        정면충돌  156    2  193
# 13     합계        측면충돌  879   12  996
# 14     합계          추돌  102    0  126
# 15     합계         횡단중  198    1  212
# 16     합계       후진중충돌    2    0    2
# 17     합계       공작물충돌   36    2   34
# 18     합계   주/정차차량 충돌    1    0    1
# 19     합계     도로이탈 추락    9    0    9
# 20     합계     도로이탈 기타    4    0    4
# 21     합계          전도  104    8   97
# 22     합계          전복    2    0    2
# 23     합계        전도전복   12    2   10
# ...

# %%
df_type_man = df_type[30:35]
df_type_man.drop(['index'], axis=1, inplace=True)
df_type_man = df_type_man.set_index(['사고유형'])
df_type_man
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#            사고건수 사망자수 부상자수
# 사고유형
# 횡단중         198    1  212
# 차도통행중        64    0   70
# 길가장자리구역통행중   34    0   35
# 보도통행중       364    0  375
# 횡단중         198    1  212

# %%
df_type_car = df_type[38:42]
df_type_car.drop(['index'], axis=1, inplace=True)
df_type_car = df_type_car.set_index(['사고유형'])
df_type_car
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       사고건수 사망자수 부상자수
# 사고유형
# 후진중충돌    2    0    2
# 정면충돌   156    2  193
# 측면충돌   879   12  996
# 추돌     102    0  126

# %%
df_type_carself = df_type[46:53]
df_type_carself.drop(['index'], axis=1, inplace=True)
df_type_carself = df_type_carself.set_index(['사고유형'])
df_type_carself
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           사고건수 사망자수 부상자수
# 사고유형
# 공작물충돌       36    2   34
# 주/정차차량 충돌    1    0    1
# 도로이탈 추락      9    0    9
# 도로이탈 기타      4    0    4
# 전도         104    8   97
# 전복           2    0    2
# 전도전복        12    2   10
