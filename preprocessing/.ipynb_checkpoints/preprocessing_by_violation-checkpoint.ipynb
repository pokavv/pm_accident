# %%
from matplotlib import font_manager, rc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

font_name = font_manager.FontProperties(fname='c:/windows/fonts/malgun.ttf').get_name()
rc('font', family=font_name)

# %%
df = pd.read_excel('data/accident_법규위반별.xls')
df
# Out:
#                                                 기준년도 2017 2017.1 2017.2  \
# 0                                               기준년도   합계     합계     합계
# 1                                               기준년도   합계  중앙선침범   신호위반
# 2                                               사고건수  117      8      4
# 3                                               사망자수    4      0      0
# 4                                               부상자수  124     10      5
# 5  출처)도로교통공단.&#10;주) 부상자수는 중상자수，경상자수，부상신고자수의 합계.&...  NaN    NaN    NaN
#
#     2017.3  2017.4 2017.5     2017.6     2017.7     2017.8  ...  2021.18  \
# 0       합계      합계     합계         합계         합계         합계  ...  운전자법규위반
# 1  안전거리미확보  일시정지위반  부당한회전  안전운전의무불이행  교차로운행방법위반  보행자보호의무위반  ...  안전거리미확보
# 2        3       1      1         82          6          3  ...       31
# 3        1       0      0          3          0          0  ...        0
# 4        2       1      1         83          8          4  ...       35
# ...

# %%
df = df.drop(df.index[0])
df = df.drop(df.index[4])
df
# Out:
#    기준년도 2017 2017.1 2017.2   2017.3  2017.4 2017.5     2017.6     2017.7  \
# 1  기준년도   합계  중앙선침범   신호위반  안전거리미확보  일시정지위반  부당한회전  안전운전의무불이행  교차로운행방법위반
# 2  사고건수  117      8      4        3       1      1         82          6
# 3  사망자수    4      0      0        1       0      0          3          0
# 4  부상자수  124     10      5        2       1      1         83          8
#
#       2017.8  ...  2021.18 2021.19 2021.20  2021.21    2021.22    2021.23  \
# 1  보행자보호의무위반  ...  안전거리미확보  일시정지위반   부당한회전  진로양보불이행  안전운전의무불이행  교차로운행방법위반
# 2          3  ...       31       5      46        1       1013         31
# 3          0  ...        0       0       0        0         14          0
# 4          4  ...       35       6      53        2       1094         40
#
#      2021.24     2021.25    2021.26 2021.27
# 1  보행자보호의무위반  차로위반(진로변경)  직진우회전진행방해      기타
# 2         40           4         48     263
# 3          0           0          0       1
# 4         41          10         56     269
#
# ...

# %%
dft = df.transpose()
dft
# Out:
#                   1     2     3     4
# 기준년도           기준년도  사고건수  사망자수  부상자수
# 2017             합계   117     4   124
# 2017.1        중앙선침범     8     0    10
# 2017.2         신호위반     4     0     5
# 2017.3      안전거리미확보     3     1     2
# ...             ...   ...   ...   ...
# 2021.23   교차로운행방법위반    31     0    40
# 2021.24   보행자보호의무위반    40     0    41
# 2021.25  차로위반(진로변경)     4     0    10
# 2021.26   직진우회전진행방해    48     0    56
# 2021.27          기타   263     1   269
#
# [129 rows x 4 columns]

# %%
df_sum = dft[dft[1] == '합계']
df_sum.drop([1], axis=1, inplace=True)
df_sum = df_sum.reset_index()
df_sum = df_sum.drop_duplicates([2])
df_sum.columns = ['기준년도', '사고건수', '사망자수', '부상자수']
df_sum = df_sum.set_index(['기준년도'])
df_sum
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_7300\2518687585.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sum.drop([1], axis=1, inplace=True)
#       사고건수 사망자수  부상자수
# 기준년도
# 2017   117    4   124
# 2018   225    4   238
# 2019   447    8   473
# 2020   897   10   985
# 2021  1735   19  1901

# %%
df_violation = dft[dft[1] != '합계']
pd.set_option('display.max_rows', None)
df_violation
# Out:
#                   1     2     3     4
# 기준년도           기준년도  사고건수  사망자수  부상자수
# 2017.1        중앙선침범     8     0    10
# 2017.2         신호위반     4     0     5
# 2017.3      안전거리미확보     3     1     2
# 2017.4       일시정지위반     1     0     1
# 2017.5        부당한회전     1     0     1
# 2017.6    안전운전의무불이행    82     3    83
# 2017.7    교차로운행방법위반     6     0     8
# 2017.8    보행자보호의무위반     3     0     4
# 2017.9    직진우회전진행방해     1     0     1
# 2017.10          기타     8     0     9
# 2017.12       중앙선침범     8     0    10
# 2017.13        신호위반     4     0     5
# 2017.14     안전거리미확보     3     1     2
# 2017.15      일시정지위반     1     0     1
# 2017.16       부당한회전     1     0     1
# 2017.17   안전운전의무불이행    82     3    83
# 2017.18   교차로운행방법위반     6     0     8
# 2017.19   보행자보호의무위반     3     0     4
# 2017.20   직진우회전진행방해     1     0     1
# 2017.21          기타     8     0     9
# 2018.1     앞지르기금지위반     1     0     1
# 2018.2        중앙선침범    15     0    16
# 2018.3         신호위반    28     2    29
# ...

# %%
df_violation = df_violation[df_violation[1] != '기타']
df_violation
# Out:
#                   1     2     3     4
# 기준년도           기준년도  사고건수  사망자수  부상자수
# 2017.1        중앙선침범     8     0    10
# 2017.2         신호위반     4     0     5
# 2017.3      안전거리미확보     3     1     2
# 2017.4       일시정지위반     1     0     1
# 2017.5        부당한회전     1     0     1
# 2017.6    안전운전의무불이행    82     3    83
# 2017.7    교차로운행방법위반     6     0     8
# 2017.8    보행자보호의무위반     3     0     4
# 2017.9    직진우회전진행방해     1     0     1
# 2017.12       중앙선침범     8     0    10
# 2017.13        신호위반     4     0     5
# 2017.14     안전거리미확보     3     1     2
# 2017.15      일시정지위반     1     0     1
# 2017.16       부당한회전     1     0     1
# 2017.17   안전운전의무불이행    82     3    83
# 2017.18   교차로운행방법위반     6     0     8
# 2017.19   보행자보호의무위반     3     0     4
# 2017.20   직진우회전진행방해     1     0     1
# 2018.1     앞지르기금지위반     1     0     1
# 2018.2        중앙선침범    15     0    16
# 2018.3         신호위반    28     2    29
# 2018.4      안전거리미확보     4     0     4
# 2018.5        부당한회전     6     0     7
# ...

# %%
df_violation.columns = ['법규위반', '사고건수', '사망자수', '부상자수']
df_violation = df_violation.drop('기준년도')
df_violation = df_violation.reset_index()

# %%
df_violation_2017 = df_violation[0:9]
df_violation_2017.drop(['index'], axis=1, inplace=True)
df_violation_2017 = df_violation_2017.set_index(['법규위반'])
df_violation_2017
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_7300\1940951522.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_violation_2017.drop(['index'], axis=1, inplace=True)
#           사고건수 사망자수 부상자수
# 법규위반
# 중앙선침범        8    0   10
# 신호위반         4    0    5
# 안전거리미확보      3    1    2
# 일시정지위반       1    0    1
# 부당한회전        1    0    1
# 안전운전의무불이행   82    3   83
# 교차로운행방법위반    6    0    8
# 보행자보호의무위반    3    0    4
# 직진우회전진행방해    1    0    1

# %%
df_violation_2018 = df_violation[18:29]
df_violation_2018.drop(['index'], axis=1, inplace=True)
df_violation_2018 = df_violation_2018.set_index(['법규위반'])
df_violation_2018
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_7300\1275410309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_violation_2018.drop(['index'], axis=1, inplace=True)
#            사고건수 사망자수 부상자수
# 법규위반
# 앞지르기금지위반      1    0    1
# 중앙선침범        15    0   16
# 신호위반         28    2   29
# 안전거리미확보       4    0    4
# 부당한회전         6    0    7
# 우선권양보불이행      1    0    1
# 안전운전의무불이행   143    2  152
# 교차로운행방법위반     3    0    3
# 보행자보호의무위반     2    0    2
# 차로위반(진로변경)    2    0    2
# 직진우회전진행방해     5    0    6

# %%
df_violation_2019 = df_violation[40:51]
df_violation_2019.drop(['index'], axis=1, inplace=True)
df_violation_2019 = df_violation_2019.set_index(['법규위반'])
df_violation_2019
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_7300\962879941.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_violation_2019.drop(['index'], axis=1, inplace=True)
#            사고건수 사망자수 부상자수
# 법규위반
# 앞지르기방법위반      1    0    1
# 중앙선침범        28    0   31
# 신호위반         42    1   46
# 안전거리미확보       9    0   10
# 일시정지위반        1    0    1
# 부당한회전        14    0   16
# 안전운전의무불이행   265    7  274
# 교차로운행방법위반    24    0   28
# 보행자보호의무위반     6    0    6
# 차로위반(진로변경)    1    0    1
# 직진우회전진행방해    10    0   11

# %%
df_violation_2020 = df_violation[62:73]
df_violation_2020.drop(['index'], axis=1, inplace=True)
df_violation_2020 = df_violation_2020.set_index(['법규위반'])
df_violation_2020
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_7300\2889147400.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_violation_2020.drop(['index'], axis=1, inplace=True)
#            사고건수 사망자수 부상자수
# 법규위반
# 과속            1    0    1
# 중앙선침범        50    1   54
# 신호위반         75    3   87
# 안전거리미확보      16    1   17
# 일시정지위반        3    0    3
# 부당한회전        23    0   27
# 안전운전의무불이행   529    4  582
# 교차로운행방법위반    30    1   34
# 보행자보호의무위반    21    0   22
# 차로위반(진로변경)    1    0    1
# 직진우회전진행방해    20    0   24

# %%
df_violation_2021 = df_violation[84:96]
df_violation_2021.drop(['index'], axis=1, inplace=True)
df_violation_2021 = df_violation_2021.set_index(['법규위반'])
df_violation_2021
# Out:
# C:\Users\me\AppData\Local\Temp\ipykernel_7300\1165000677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_violation_2021.drop(['index'], axis=1, inplace=True)
#             사고건수 사망자수  부상자수
# 법규위반
# 앞지르기방법위반       1    0     1
# 중앙선침범        107    1   128
# 신호위반         145    3   166
# 안전거리미확보       31    0    35
# 일시정지위반         5    0     6
# 부당한회전         46    0    53
# 진로양보불이행        1    0     2
# 안전운전의무불이행   1013   14  1094
# 교차로운행방법위반     31    0    40
# 보행자보호의무위반     40    0    41
# 차로위반(진로변경)     4    0    10
# 직진우회전진행방해     48    0    56

# %%
plt.xticks(rotation=45)
plt.plot(df_violation_2021['사고건수'])
