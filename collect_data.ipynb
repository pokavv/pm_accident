# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
accidnet_weekend = pd.read_excel('data/accident_day.xls')
accidnet_weekend
# Out:
#                                                 기준년도 2017 2017.1 2017.2  \
# 0                                               기준년도   합계      일      월
# 1                                               사고건수  117     11     17
# 2                                               사망자수    4      0      1
# 3                                               부상자수  124     12     18
# 4  출처)도로교통공단.&#10;주) 부상자수는 중상자수，경상자수，부상신고자수의 합계.&...  NaN    NaN    NaN
#
#   2017.3 2017.4 2017.5 2017.6 2017.7 2018  ... 2020.6 2020.7  2021 2021.1  \
# 0      화      수      목      금      토   합계  ...      금      토    합계      일
# 1     19     18     20     13     19  225  ...    132    131  1735    235
# 2      1      0      1      0      1    4  ...      1      2    19      6
# 3     21     19     19     14     21  238  ...    144    142  1901    260
# 4    NaN    NaN    NaN    NaN    NaN  NaN  ...    NaN    NaN   NaN    NaN
#
#   2021.2 2021.3 2021.4 2021.5 2021.6 2021.7
# ...

# %%
accidnet_month = pd.read_excel('data/accident_month.xls')
accidnet_month
# Out:
#                                              월별 교통사고 Unnamed: 1 Unnamed: 2  \
# 0                                        (단위 : 건, 명)        NaN        NaN
# 1                                               기준년도       2017       2017
# 2                                               기준년도         합계        02월
# 3                                               사고건수        117          2
# 4                                               사망자수          4          0
# 5                                               부상자수        124          2
# 6  출처)도로교통공단.&#10;주) 부상자수는 중상자수，경상자수，부상신고자수의 합계.&...        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       2017       2017       2017       2017       2017       2017
# 2        03월        04월        05월        06월        07월        08월
# 3          4          4         15          7         13         17
# ...

# %%
accidnet_time = pd.read_excel('data/accident_time.xls')
accidnet_time
# Out:
#                                   기준년도 2017 2017.1 2017.2 2017.3 2017.4  \
# 0                                 기준년도   합계  0시~2시  2시~4시  4시~6시  6시~8시
# 1                                 사고건수  117      6      8      1      7
# 2                                 사망자수    4      1      1      0      0
# 3                                 부상자수  124      5      7      1      7
# 4  주) 부상자수는 중상자수，경상자수，부상신고자수의 합계.&#10;  NaN    NaN    NaN    NaN    NaN
#
#    2017.5   2017.6   2017.7   2017.8  ... 2021.3 2021.4  2021.5   2021.6  \
# 0  8시~10시  10시~12시  12시~14시  14시~16시  ...  4시~6시  6시~8시  8시~10시  10시~12시
# 1      20       10        6       10  ...     28     52     135      122
# 2       0        0        0        1  ...      2      1       2        1
# 3      20       11        6        9  ...     30     57     141      136
# 4     NaN      NaN      NaN      NaN  ...    NaN    NaN     NaN      NaN
#
#     2021.7   2021.8   2021.9  2021.10  2021.11  2021.12
# ...

# %%
accidnet_type = pd.read_excel('data/accident_type.xls')
accidnet_type
# Out:
#                                                  기준년도    합계 합계.1   합계.2  \
# 0                                                기준년도    합계   합계     합계
# 1                                                기준년도    합계   합계     합계
# 2                                                기준년도    합계  횡단중  후진중충돌
# 3                                                사고건수  3421  198      2
# 4                                                사망자수    45    1      0
# 5                                                부상자수  3721  212      2
# 6                                                 NaN   NaN  NaN    NaN
# 7                                                 NaN   NaN  NaN    NaN
# 8                                                 NaN   NaN  NaN    NaN
# 9                                                 NaN   NaN  NaN    NaN
# 10                                                NaN   NaN  NaN    NaN
# 11                                                NaN   NaN  NaN    NaN
# ...
