# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.rcParams['font.family'] = 'NanumGothic'

df = pd.read_excel('data/Report.xls', index_col=0)
df
# Out:
#                  01월  02월  03월  04월  05월  06월  07월  08월  09월  10월  11월  12월
# 가해운전자 차량용도 대분류
# 개인형이동수단(PM)       55   51  133  173  166  167  186  181  184  174  152  113

# %%
df = df.loc['개인형이동수단(PM)']

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='개인형이동수단(PM)'>
